# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# Libraries
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1 - Index Functions
#
# In this challenge, we will practice the advanced functions introduced in the lesson. However, before we start, we will load and evaluate our dataset.
#
# Load the dataset from Ironhack's database:
# * db: `admissions predict`
# * table: `admissions predict`

# %%
# your code here
df_admissions_predict = pd.read_csv('data/Admission_Predict.csv')
df_admissions_predict
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        316          104                  3  3.0   3.5  8.00
# 2             3        322          110                  3  3.5   2.5  8.67
# 3             4        314          103                  2  2.0   3.0  8.21
# 4             5        330          115                  5  4.5   3.0  9.34
# ..          ...        ...          ...                ...  ...   ...   ...
# 380         381        324          110                  3  3.5   3.5  9.04
# 381         382        325          107                  3  3.0   3.5  9.11
# 382         383        330          116                  4  5.0   4.5  9.45
# 383         384        312          103                  3  3.5   4.0  8.78
# 384         385        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %% [markdown]
# Remove trailing spaces at the end of the column names if there are any.

# %%
# your code here
df_admissions_predict.rename(columns = lambda title: title.strip(' '), inplace = True)
df_admissions_predict
# Out:
#      GRE Score  CGPA  TOEFL Score  University Rating  SOP  LOR  Research  \
# 0          337  9.65          118                  4  4.5  4.5         1
# 1          316  8.00          104                  3  3.0  3.5         1
# 2          322  8.67          110                  3  3.5  2.5         1
# 3          314  8.21          103                  2  2.0  3.0         0
# 4          330  9.34          115                  5  4.5  3.0         1
# ..         ...   ...          ...                ...  ...  ...       ...
# 380        324  9.04          110                  3  3.5  3.5         1
# 381        325  9.11          107                  3  3.0  3.5         1
# 382        330  9.45          116                  4  5.0  4.5         1
# 383        312  8.78          103                  3  3.5  4.0         0
# 384        333  9.66          117                  4  5.0  4.0         1
#
#      Chance of Admit  CGPA_std   GRE_std
# 0               0.92  1.750174  1.755663
# ...

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
# your code here
df_admissions_predict.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        316          104                  3  3.0   3.5  8.00
# 2           3        322          110                  3  3.5   2.5  8.67
# 3           4        314          103                  2  2.0   3.0  8.21
# 4           5        330          115                  5  4.5   3.0  9.34
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.72
# 2         1              0.80
# 3         0              0.65
# 4         1              0.90

# %% [markdown]
# Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
# your code here
df_admissions_predict.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df_admissions_predict.isna().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
# your code here
df_admissions_predict.set_index('Serial No.', inplace=True)
df_admissions_predict
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 316          104                  3  3.0   3.5  8.00
# 3                 322          110                  3  3.5   2.5  8.67
# 4                 314          103                  2  2.0   3.0  8.21
# 5                 330          115                  5  4.5   3.0  9.34
# ...               ...          ...                ...  ...   ...   ...
# 381               324          110                  3  3.5   3.5  9.04
# 382               325          107                  3  3.0   3.5  9.11
# 383               330          116                  4  5.0   4.5  9.45
# 384               312          103                  3  3.5   4.0  8.78
# 385               333          117                  4  5.0   4.0  9.66
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# ...

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %%
# your code here
df_admissions_predict.set_index(['GRE Score', 'CGPA'])
# Out:
#                 TOEFL Score  University Rating  SOP  LOR   Research  \
# GRE Score CGPA
# 337       9.65          118                  4  4.5   4.5         1
# 316       8.00          104                  3  3.0   3.5         1
# 322       8.67          110                  3  3.5   2.5         1
# 314       8.21          103                  2  2.0   3.0         0
# 330       9.34          115                  5  4.5   3.0         1
# ...                     ...                ...  ...   ...       ...
# 324       9.04          110                  3  3.5   3.5         1
# 325       9.11          107                  3  3.0   3.5         1
# 330       9.45          116                  4  5.0   4.5         1
# 312       8.78          103                  3  3.5   4.0         0
# 333       9.66          117                  4  5.0   4.0         1
#
#                 Chance of Admit
# GRE Score CGPA
# 337       9.65              0.92
# 316       8.00              0.72
# ...

# %%
df_admissions_predict
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 316          104                  3  3.0   3.5  8.00
# 3                 322          110                  3  3.5   2.5  8.67
# 4                 314          103                  2  2.0   3.0  8.21
# 5                 330          115                  5  4.5   3.0  9.34
# ...               ...          ...                ...  ...   ...   ...
# 381               324          110                  3  3.5   3.5  9.04
# 382               325          107                  3  3.0   3.5  9.11
# 383               330          116                  4  5.0   4.5  9.45
# 384               312          103                  3  3.5   4.0  8.78
# 385               333          117                  4  5.0   4.0  9.66
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# ...

# %% [markdown]
# Replace the index with an index comprised of two columns - `GRE Score` and `CGPA`. Remove the columns from the dataset as well. Make sure to use `inplace=True`.

# %%
df_admissions_predict.set_index(['GRE Score', 'CGPA'], inplace = True)
df_admissions_predict
# Out:
#                 TOEFL Score  University Rating  SOP  LOR   Research  \
# GRE Score CGPA
# 337       9.65          118                  4  4.5   4.5         1
# 316       8.00          104                  3  3.0   3.5         1
# 322       8.67          110                  3  3.5   2.5         1
# 314       8.21          103                  2  2.0   3.0         0
# 330       9.34          115                  5  4.5   3.0         1
# ...                     ...                ...  ...   ...       ...
# 324       9.04          110                  3  3.5   3.5         1
# 325       9.11          107                  3  3.0   3.5         1
# 330       9.45          116                  4  5.0   4.5         1
# 312       8.78          103                  3  3.5   4.0         0
# 333       9.66          117                  4  5.0   4.0         1
#
#                 Chance of Admit
# GRE Score CGPA
# 337       9.65              0.92
# 316       8.00              0.72
# ...

# %% [markdown]
# Now change the index back to a sequence starting at zero using the `reset_index` function. Make sure to use `inplace=True`.

# %%
# your code here
df_admissions_predict.reset_index(inplace = True)
df_admissions_predict
# Out:
#      GRE Score  CGPA  TOEFL Score  University Rating  SOP  LOR   Research  \
# 0          337  9.65          118                  4  4.5   4.5         1
# 1          316  8.00          104                  3  3.0   3.5         1
# 2          322  8.67          110                  3  3.5   2.5         1
# 3          314  8.21          103                  2  2.0   3.0         0
# 4          330  9.34          115                  5  4.5   3.0         1
# ..         ...   ...          ...                ...  ...   ...       ...
# 380        324  9.04          110                  3  3.5   3.5         1
# 381        325  9.11          107                  3  3.0   3.5         1
# 382        330  9.45          116                  4  5.0   4.5         1
# 383        312  8.78          103                  3  3.5   4.0         0
# 384        333  9.66          117                  4  5.0   4.0         1
#
#      Chance of Admit
# 0                0.92
# 1                0.72
# ...

# %% [markdown]
# # Challenge 2 - Advanced Functions
#
# In this part of the lab, we would like to test complex conditions on the entire dataset at once. Let's start by finding the number of rows where the CGPA is higher than 9 and the student has conducted research.

# %%
#your code here
condition_1 = (df_admissions_predict['CGPA'] > 9) & (df_admissions_predict['Research'] == 1)
df_admissions_predict[condition_1]
# Out:
#      GRE Score  CGPA  TOEFL Score  University Rating  SOP  LOR   Research  \
# 0          337  9.65          118                  4  4.5   4.5         1
# 4          330  9.34          115                  5  4.5   3.0         1
# 10         328  9.10          112                  4  4.0   4.5         1
# 19         328  9.50          116                  5  5.0   5.0         1
# 20         334  9.70          119                  5  5.0   4.5         1
# ..         ...   ...          ...                ...  ...   ...       ...
# 379        329  9.23          111                  4  4.5   4.0         1
# 380        324  9.04          110                  3  3.5   3.5         1
# 381        325  9.11          107                  3  3.0   3.5         1
# 382        330  9.45          116                  4  5.0   4.5         1
# 384        333  9.66          117                  4  5.0   4.0         1
#
#      Chance of Admit
# 0                0.92
# 4                0.90
# ...

# %% [markdown]
# Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
# your code here
condition_2 = (df_admissions_predict['CGPA'] > 9) & (df_admissions_predict['SOP'] < 3.5)
df_condition_2 = df_admissions_predict[condition_2]
df_condition_2
# Out:
#      GRE Score  CGPA  TOEFL Score  University Rating  SOP  LOR   Research  \
# 28         338  9.40          118                  4  3.0   4.5         1
# 62         327  9.02          114                  3  3.0   3.0         0
# 140        326  9.11          114                  3  3.0   3.0         1
# 217        324  9.01          111                  4  3.0   3.0         1
# 381        325  9.11          107                  3  3.0   3.5         1
#
#      Chance of Admit
# 28               0.91
# 62               0.61
# 140              0.83
# 217              0.82
# 381              0.84

# %%
df_condition_2['Chance of Admit '].mean()
# Out:
# 0.8019999999999999

# %% [markdown]
# We would like to create a deciding factor column for each student. We standardize several columns and then pick the most important factor from a lookup table. If the standardized value is above 0.8, the student will be accepted.
#
# We will start by creating a standardized column for `CGPA`, `GRE Score` and `LOR`. We will name these columns `CGPA_std`, `GRE_std`, and `LOR_std` respecively.
#
# Recall that standardizing a column is done by subtracting the mean of the column from all observations in the column and then dividing each observation in the column by the column's standard deviation.
#
# In the cell below, write a standardization function (a function that takes a column as input and returns a standardized column as output). Make sure to use the `numpy` versions of mean and standard deviation.

# %%
def standardize(col):
    """
    This function takes a column from a dataframe 
    and returns a standardized column by subtracting the column's mean
    and dividing by the column's standard deviation.
    """    
    # your code here
    stan_col = (col - np.mean(col)) / np.std(col)
    return stan_col

# %% [markdown]
# Now create the standardized columns `CGPA_std`, `GRE_std`, and `LOR_std` and add them to the `admissions` dataframe.

# %%
standardize(df_admissions_predict['LOR'])
# Out:
# 0      1.193197
# 1      0.076840
# 2     -1.039517
# 3     -0.481338
# 4     -0.481338
#          ...
# 380    0.076840
# 381    0.076840
# 382    1.193197
# 383    0.635019
# 384    0.635019
# Name: LOR, Length: 385, dtype: float64

# %%
# your code here
df_admissions_predict['CGPA_std'] = standardize(df_admissions_predict['CGPA'])
df_admissions_predict['GRE_std'] = standardize(df_admissions_predict['GRE Score'])
df_admissions_predict['LOR_std'] = standardize(df_admissions_predict['LOR'])
df_admissions_predict['LOR_std_2'] = df_admissions_predict['LOR'].apply(standardize)
df_admissions_predict
# Out:
#      GRE Score  CGPA  TOEFL Score  University Rating  SOP  LOR  Research  \
# 0          337  9.65          118                  4  4.5  4.5         1
# 1          316  8.00          104                  3  3.0  3.5         1
# 2          322  8.67          110                  3  3.5  2.5         1
# 3          314  8.21          103                  2  2.0  3.0         0
# 4          330  9.34          115                  5  4.5  3.0         1
# ..         ...   ...          ...                ...  ...  ...       ...
# 380        324  9.04          110                  3  3.5  3.5         1
# 381        325  9.11          107                  3  3.0  3.5         1
# 382        330  9.45          116                  4  5.0  4.5         1
# 383        312  8.78          103                  3  3.5  4.0         0
# 384        333  9.66          117                  4  5.0  4.0         1
#
#      Chance of Admit  CGPA_std   GRE_std   LOR_std  LOR_std_2
# ...

# %% [markdown]
# NOTE FOR TEACHING TEAM (OR MIGHT BE ASKED DURING CLASS) : WHY APPLY GIVES US NAN HERE?

# %% [markdown]
# We will generate the decision choice at random using the code below. Please run the cell.

# %%
# Libraries
from random import choices

# %%
std_columns = ['CGPA_std', 'GRE_std', 'LOR_std']

decision_choice = choices(std_columns, k=df_admissions_predict.shape[0])
decision_choice
# Out:
# ['LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
# ...

# %% [markdown]
# Now create the deciding column using the `lookup` function. The lookup column is `decision_choice` found above. Call the column resulting from the lookup function `deciding_column` and add it to the `admissions` dataframe.

# %%
# your code here
df_admissions_predict['deciding_column'] = decision_choice
df_admissions_predict.head()
# Out:
#    GRE Score  CGPA  TOEFL Score  University Rating  SOP  LOR  Research  \
# 0        337  9.65          118                  4  4.5  4.5         1
# 1        316  8.00          104                  3  3.0  3.5         1
# 2        322  8.67          110                  3  3.5  2.5         1
# 3        314  8.21          103                  2  2.0  3.0         0
# 4        330  9.34          115                  5  4.5  3.0         1
#
#    Chance of Admit  CGPA_std   GRE_std   LOR_std  LOR_std_2 deciding_column
# 0             0.92  1.750174  1.755663  1.193197        NaN         LOR_std
# 1             0.72 -0.992501 -0.063450  0.076840        NaN         GRE_std
# 2             0.80  0.121191  0.456297 -1.039517        NaN         LOR_std
# 3             0.65 -0.643433 -0.236698 -0.481338        NaN         GRE_std
# 4             0.90  1.234884  1.149292 -0.481338        NaN         GRE_std

# %% [markdown]
# Create a column called `decision` in the `admissions` dataframe. Assign 1 to this column if the value of `deciding_column` is greater than 0.8 and 0 otherwise.

# %%
#Here we can access the value of a standart column bases on the value of deciding column. We need to apply this to the table
df_admissions_predict[df_admissions_predict.loc[0]['deciding_column']][0]
# Out:
# 1.1931973013971253

# %%
decision = []
for i in range(df_admissions_predict.shape[0]):
    standard_number = df_admissions_predict[df_admissions_predict.loc[i]['deciding_column']][i] 
    if standard_number >= 0.8:
        decision.append(1)
    else:
        decision.append(0)
df_admissions_predict['Decision'] = decision
df_admissions_predict
# Out:
#      GRE Score  CGPA  TOEFL Score  University Rating  SOP  LOR  Research  \
# 0          337  9.65          118                  4  4.5  4.5         1
# 1          316  8.00          104                  3  3.0  3.5         1
# 2          322  8.67          110                  3  3.5  2.5         1
# 3          314  8.21          103                  2  2.0  3.0         0
# 4          330  9.34          115                  5  4.5  3.0         1
# ..         ...   ...          ...                ...  ...  ...       ...
# 380        324  9.04          110                  3  3.5  3.5         1
# 381        325  9.11          107                  3  3.0  3.5         1
# 382        330  9.45          116                  4  5.0  4.5         1
# 383        312  8.78          103                  3  3.5  4.0         0
# 384        333  9.66          117                  4  5.0  4.0         1
#
#      Chance of Admit  CGPA_std   GRE_std   LOR_std  LOR_std_2 deciding_column  \
# ...

# %% [markdown]
# How many applicants will be accepted to the program using the decision column? Compute the result below.

# %%
# your code here
df_admissions_predict['Decision'].value_counts()
# Out:
# Decision
# 0    295
# 1     90
# Name: count, dtype: int64

# %% [markdown]
# # Challenge 3 - Method Chaining
#
# To increase our coding efficiency, let's make a number of changes to our dataframe in one line of code.
#
# In the cell below, remove all non character symbols from the column names, replace all spaces in column names to underscores, and change all upper case characters to lower case. Assign these new column values to `admissions.columns`.

# %%
df_admissions_predict.head()
# Out:
#    GRE Score  CGPA  TOEFL Score  University Rating  SOP  LOR  Research  \
# 0        337  9.65          118                  4  4.5  4.5         1
# 1        316  8.00          104                  3  3.0  3.5         1
# 2        322  8.67          110                  3  3.5  2.5         1
# 3        314  8.21          103                  2  2.0  3.0         0
# 4        330  9.34          115                  5  4.5  3.0         1
#
#    Chance of Admit  CGPA_std   GRE_std   LOR_std  LOR_std_2 deciding_column  \
# 0             0.92  1.750174  1.755663  1.193197        NaN         LOR_std
# 1             0.72 -0.992501 -0.063450  0.076840        NaN         GRE_std
# 2             0.80  0.121191  0.456297 -1.039517        NaN         LOR_std
# 3             0.65 -0.643433 -0.236698 -0.481338        NaN         GRE_std
# 4             0.90  1.234884  1.149292 -0.481338        NaN         GRE_std
#
#    Decision
# 0         1
# 1         0
# 2         0
# 3         0
# 4         1

# %%
# your code here
df_admissions_predict.columns = df_admissions_predict.columns.str.lower()

# %%
df_admissions_predict.head()
# Out:
#    gre score  cgpa  toefl score  university rating  sop  lor  research  \
# 0        337  9.65          118                  4  4.5  4.5         1
# 1        316  8.00          104                  3  3.0  3.5         1
# 2        322  8.67          110                  3  3.5  2.5         1
# 3        314  8.21          103                  2  2.0  3.0         0
# 4        330  9.34          115                  5  4.5  3.0         1
#
#    chance of admit  cgpa_std   gre_std   lor_std  lor_std_2 deciding_column  \
# 0             0.92  1.750174  1.755663  1.193197        NaN         LOR_std
# 1             0.72 -0.992501 -0.063450  0.076840        NaN         GRE_std
# 2             0.80  0.121191  0.456297 -1.039517        NaN         LOR_std
# 3             0.65 -0.643433 -0.236698 -0.481338        NaN         GRE_std
# 4             0.90  1.234884  1.149292 -0.481338        NaN         GRE_std
#
#    decision
# 0         1
# 1         0
# 2         0
# 3         0
# 4         1

# %%
df_admissions_predict.columns = pd.DataFrame(df_admissions_predict.columns).apply(lambda x: x.str.replace(' ', '_'))

# %%
df_admissions_predict
# Out:
#      (gre_score,)  (cgpa,)  (toefl_score,)  (university_rating,)  (sop,)  \
# 0             337     9.65             118                     4     4.5
# 1             316     8.00             104                     3     3.0
# 2             322     8.67             110                     3     3.5
# 3             314     8.21             103                     2     2.0
# 4             330     9.34             115                     5     4.5
# ..            ...      ...             ...                   ...     ...
# 380           324     9.04             110                     3     3.5
# 381           325     9.11             107                     3     3.0
# 382           330     9.45             116                     4     5.0
# 383           312     8.78             103                     3     3.5
# 384           333     9.66             117                     4     5.0
#
#      (lor,)  (research,)  (chance_of_admit,)  (cgpa_std,)  (gre_std,)  \
# ...

# %% [markdown]
# In the cell below, give all student with a university rating of 4 or higher a 10 point boost on their GRE score and split the column into 4 bins using the `cut` function. Assign this new score to the variable `adjusted_gre`.

# %%
# your code here
df_admissions_predict['adjusted_gre'] = df_admissions_predict['GRE Score'].apply(lambda x: x+10 if df_admissions_predict['University Rating'] <= 4 else x)
df_admissions_predict
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4492\2003014484.py in ?()
#       1 # your code here
# ----> 2 df_admissions_predict['GRE Score'].applymap(lambda x: x+10 if df_admissions_predict['University Rating'] <= 4 else x)
#
# c:\Users\misol\anaconda3\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'applymap'
